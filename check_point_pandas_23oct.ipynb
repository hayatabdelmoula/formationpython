# %%
import pandas as pd
import numpy as np
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data , index=labels)
print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.loc['k'] = ['Suresh','15.5', '1','yes']

# %%
df
# Out:
#         name score attempts qualify
# a  Anastasia  12.5        1     yes
# b       Dima   9.0        3      no
# c  Katherine  16.5        2     yes
# d      James   NaN        3      no
# e      Emily   9.0        2      no
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# j      Jonas  19.0        1     yes
# k     Suresh  15.5        1     yes

# %%
df.pop('attempts')
# Out:
# a    1
# b    3
# c    2
# d    3
# e    2
# f    3
# g    1
# h    1
# i    2
# j    1
# k    1
# Name: attempts, dtype: object

# %%
df
# Out:
#         name score qualify
# a  Anastasia  12.5     yes
# b       Dima   9.0      no
# c  Katherine  16.5     yes
# d      James   NaN      no
# e      Emily   9.0      no
# f    Michael  20.0     yes
# g    Matthew  14.5     yes
# h      Laura   NaN      no
# i      Kevin   8.0      no
# j      Jonas  19.0     yes
# k     Suresh  15.5     yes

# %%
df.[success] = ['15.5', '1','yes']
# Out:
#   File "<ipython-input-15-04446c9c9cc1>", line 1
#     df.[success] = ['15.5', '1','yes']
#        ^
# SyntaxError: invalid syntax

# %%
def f(row):
    if row['score'] > 10:
        val = 0
    else:
        val = 1
    return val

# %%
df['success']=df.apply(f, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-9ae4cba0ad47> in <module>
# ----> 1 df['success']=df.apply(f, axis=1)
#
# ~\anaconda4\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda4\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda4\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda4\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-48-3ad67caf83c5> in f(row)
#       1 def f(row):
# ----> 2     if row['score'] > 10:
#       3         val = 0
#       4     else:
#       5         val = 1
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         name score qualify
# a  Anastasia  12.5     yes
# b       Dima   9.0      no
# c  Katherine  16.5     yes
# e      Emily   9.0      no
# f    Michael  20.0     yes
# g    Matthew  14.5     yes
# i      Kevin   8.0      no
# j      Jonas  19.0     yes
# k     Suresh  15.5     yes

# %%
df['success']=df.apply(f, axis=1)

# %%
df
# Out:
#         name  score qualify  success
# a  Anastasia   12.5     yes        0
# b       Dima    9.0      no        1
# c  Katherine   16.5     yes        0
# e      Emily    9.0      no        1
# f    Michael   20.0     yes        0
# g    Matthew   14.5     yes        0
# i      Kevin    8.0      no        1
# j      Jonas   19.0     yes        0
# k     Suresh   15.5     yes        0

# %%
df["score"] = df["score"].apply(pd.to_numeric)

# %%
df = df.astype({"score": int})

# %%
df.to_csv(r'my_data.csv')
